# %% [markdown]
# Strategic Level KPIs are as follows :
# Graduation Rate: Line chart to show trends over time.
# Post-Secondary Enrollment Rate: Bar chart to compare rates across years or demographics.
# Student Achievement: Histogram to display the distribution of scores.
# Budget Utilization: Pie chart to show the allocation of funds.
# Community Engagement: Bar chart to compare engagement over different events or time periods.
#
# Below are the visualisations for the KPIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style('whitegrid')

# Strategic Level KPIs Visualization
plt.figure(figsize=(15, 10))

# Graduation Rate Line Chart
plt.subplot(3, 2, 1)
plt.plot(strategic_df['Graduation Rate'], marker='o')
plt.title('Graduation Rate Over Time')
plt.xlabel('Year')
plt.ylabel('Graduation Rate (%)')

# Post-Secondary Enrollment Rate Bar Chart
plt.subplot(3, 2, 2)
plt.bar(strategic_df.index, strategic_df['Post-Secondary Enrollment Rate'])
plt.title('Post-Secondary Enrollment Rate')
plt.xlabel('Year')
plt.ylabel('Enrollment Rate (%)')

# Student Achievement Histogram
plt.subplot(3, 2, 3)
plt.hist(strategic_df['Student Achievement'], bins=5)
plt.title('Student Achievement Distribution')
plt.xlabel('Achievement Score')
plt.ylabel('Frequency')

# Budget Utilization Pie Chart
plt.subplot(3, 2, 4)
plt.pie(strategic_df['Budget Utilization'], labels=strategic_df.index, autopct='%1.1f%%')
plt.title('Budget Utilization')

# Community Engagement Bar Chart
plt.subplot(3, 2, 5)
plt.bar(strategic_df.index, strategic_df['Community Engagement'])
plt.title('Community Engagement')
plt.xlabel('Event')
plt.ylabel('Number of Participants')

plt.tight_layout()
plt.show()

# %% [markdown]
# Tactical Level KPIs are as follows:
# Teacher Retention Rate: Line chart to show retention trends.
# Student Attendance Rate: Heatmap to show attendance patterns.
# Program Completion Rate: Bar chart to show completion rates for different programs.
# Parental Involvement: Scatter plot to correlate involvement with student performance.
# Staff Professional Development: Bar chart to show participation rates in development programs.
#
# Below are the visualisations for the KPIS

# %%
# Tactical Level KPIs Visualization
plt.figure(figsize=(15, 10))

# Teacher Retention Rate Line Chart
plt.subplot(3, 2, 1)
plt.plot(tactical_df['Teacher Retention Rate'], marker='o', color='orange')
plt.title('Teacher Retention Rate Over Time')
plt.xlabel('Year')
plt.ylabel('Retention Rate (%)')

# Student Attendance Rate Heatmap
plt.subplot(3, 2, 2)
sns.heatmap(tactical_df[['Student Attendance Rate']].T, annot=True, fmt='.1f', cmap='YlGnBu')
plt.title('Student Attendance Rate')
plt.xlabel('Year')
plt.ylabel('Attendance Rate (%)')

# Program Completion Rate Bar Chart
plt.subplot(3, 2, 3)
plt.bar(tactical_df.index, tactical_df['Program Completion Rate'], color='green')
plt.title('Program Completion Rate')
plt.xlabel('Program')
plt.ylabel('Completion Rate (%)')

# Parental Involvement Scatter Plot
plt.subplot(3, 2, 4)
plt.scatter(tactical_df.index, tactical_df['Parental Involvement'], color='purple')
plt.title('Parental Involvement')
plt.xlabel('Year')
plt.ylabel('Number of Parents')

# Staff Professional Development Bar Chart
plt.subplot(3, 2, 5)
plt.bar(tactical_df.index, tactical_df['Staff Professional Development'], color='red')
plt.title('Staff Professional Development Participation')
plt.xlabel('Year')
plt.ylabel('Participation Rate (%)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Operational Level KPIs are as follows :
# Classroom Utilization: Bar chart to show utilization rates of different classrooms or buildings.
# Technology Integration: Bar chart to compare technology integration across various classrooms.
# Maintenance Response Time: Line chart to show the trend in response times.
# Library Resource Usage: Bar chart to show usage rates of different resources.
# Extracurricular Participation: Pie chart to show the distribution of participation in different activities.
#
# Below are the visualisations for the KPIS

# %%
# Operational Level KPIs Visualization
plt.figure(figsize=(15, 10))

# Classroom Utilization Bar Chart
plt.subplot(3, 2, 1)
plt.bar(operational_df.index, operational_df['Classroom Utilization'], color='skyblue')
plt.title('Classroom Utilization')
plt.xlabel('Year')
plt.ylabel('Utilization Rate (%)')

# Technology Integration Bar Chart
plt.subplot(3, 2, 2)
plt.bar(operational_df.index, operational_df['Technology Integration'], color='teal')
plt.title('Technology Integration')
plt.xlabel('Year')
plt.ylabel('Integration Rate (%)')

# Maintenance Response Time Line Chart
plt.subplot(3, 2, 3)
plt.plot(operational_df['Maintenance Response Time'], marker='o', linestyle='--', color='magenta')
plt.title('Maintenance Response Time')
plt.xlabel('Year')
plt.ylabel('Response Time (hours)')

# Library Resource Usage Bar Chart
plt.subplot(3, 2, 4)
plt.bar(operational_df.index, operational_df['Library Resource Usage'], color='gold')
plt.title('Library Resource Usage')
plt.xlabel('Year')
plt.ylabel('Usage Rate (%)')

# Extracurricular Participation Pie Chart
plt.subplot(3, 2, 5)
plt.pie(operational_df['Extracurricular Participation'], labels=operational_df.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Extracurricular Participation')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dummy dataset for these KPIsis as follows-:
# We have generated random data that could represent what the DDSB might collect. After that, we will select appropriate visualizations for each KPI and discuss which tool to use for the dashboards.
# Let's proceed with creating the dummy datasets.

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# Define the KPIs for each level
strategic_kpis = {
    'Graduation Rate': np.random.uniform(80, 100, 5),
    'Post-Secondary Enrollment Rate': np.random.uniform(60, 90, 5),
    'Student Achievement': np.random.uniform(70, 95, 5),
    'Budget Utilization': np.random.uniform(75, 100, 5),
    'Community Engagement': np.random.randint(5, 20, 5)
}

tactical_kpis = {
    'Teacher Retention Rate': np.random.uniform(85, 100, 5),
    'Student Attendance Rate': np.random.uniform(90, 100, 5),
    'Program Completion Rate': np.random.uniform(70, 95, 5),
    'Parental Involvement': np.random.randint(100, 500, 5),
    'Staff Professional Development': np.random.uniform(60, 90, 5)
}

operational_kpis = {
    'Classroom Utilization': np.random.uniform(70, 100, 5),
    'Technology Integration': np.random.uniform(50, 100, 5),
    'Maintenance Response Time': np.random.uniform(1, 5, 5),  # In hours
    'Library Resource Usage': np.random.uniform(40, 90, 5),
    'Extracurricular Participation': np.random.uniform(50, 100, 5)
}

# Create DataFrames for each level
strategic_df = pd.DataFrame(strategic_kpis)
tactical_df = pd.DataFrame(tactical_kpis)
operational_df = pd.DataFrame(operational_kpis)

# Display the head of each DataFrame
dfs = {'Strategic Level': strategic_df, 'Tactical Level': tactical_df, 'Operational Level': operational_df}
for level, df in dfs.items():
    print(f'Head of {level} KPIs:')
    print(df.head())
    print('\n')
# Out:
# Head of Strategic Level KPIs:
#    Graduation Rate  Post-Secondary Enrollment Rate  Student Achievement  \
# 0        84.831339                       66.551072            85.726890
# 1        91.397306                       87.052366            72.372348
# 2        91.424540                       87.556593            85.179969
# 3        89.962822                       79.118286            79.255830
# 4        85.851446                       74.376110            71.765670
#
#    Budget Utilization  Community Engagement
# 0           93.476520                    18
# 1           85.915996                     8
# 2           81.335097                    11
# 3           99.514382                     7
# 4           83.550123                    17
#
#
# Head of Tactical Level KPIs:
#    Teacher Retention Rate  Student Attendance Rate  Program Completion Rate  \
# 0               85.480366                91.367944                88.400409
# ...

# %% [markdown]
# The Strategic Level KPIs dataset includes measures such as Graduation Rate, Post-Secondary Enrollment Rate, Student Achievement, Budget Utilization, and Community Engagement.
#
# The Tactical Level KPIs dataset contains Teacher Retention Rate, Student Attendance Rate, Program Completion Rate, Parental Involvement, and Staff Professional Development.
#
#
# The Operational Level KPIs dataset features Classroom Utilization, Technology Integration, Maintenance Response Time, Library Resource Usage, and Extracurricular Participation.
# These datasets provide a foundation for visualizing the performance indicators at each level of the school board's operations.

# %%
import pandas as pd
from tqdm.notebook import tqdm

tqdm.pandas()

# Define the KPI data
kpi_data = {
    'Objectives': [
        'Improve graduation outcomes',
        'Increase post-secondary transition',
        'Enhance student achievement',
        'Optimize budget allocation',
        'Boost community engagement',
        'Maintain teacher retention',
        'Ensure student attendance',
        'Achieve program success',
        'Foster parental involvement',
        'Support staff development',
        'Maximize classroom utilization',
        'Integrate technology in learning',
        'Streamline maintenance processes',
        'Increase library resource usage',
        'Encourage extracurricular participation'
    ],
    'What to Measure?': [
        'Graduation rate',
        'Enrollment rate in post-secondary education',
        'Student test scores and grades',
        'Percentage of budget spent vs. allocated',
        'Number of community events and participation',
        'Teacher retention rate',
        'Student daily attendance',
        'Completion rate of educational programs',
        'Parental involvement in school activities',
        'Participation in professional development',
        'Use of classroom space',
        'Use of technology in classrooms',
        'Time to complete maintenance requests',
        'Usage of library materials',
        'Participation in extracurricular activities'
    ],
    'KPI #': [
        '1.1', '1.2', '1.3', '1.4', '1.5',
        '2.1', '2.2', '2.3', '2.4', '2.5',
        '3.1', '3.2', '3.3', '3.4', '3.5'
    ],
    'Link': list(range(1, 16)),
    'KPI Name': [
        '% Graduation Rate',
        '% Post-Secondary Enrollment',
        'Average Student Achievement',
        '% Budget Utilization',
        'Community Engagement Level',
        '% Teacher Retention',
        '% Student Attendance',
        '% Program Completion',
        'Parental Involvement Index',
        '% Staff Development Participation',
        '% Classroom Utilization',
        '% Technology Integration',
        'Average Maintenance Response Time',
        '% Library Resource Usage',
        '% Extracurricular Participation'
    ],
    'Formula': [
        'Total Graduates / Total Students * 100',
        'Students Enrolled in Post-Secondary / High School Graduates * 100',
        'Sum of Student Scores / Total Assessments',
        'Actual Budget Spent / Total Budget * 100',
        'Total Participants / Total Events',
        'Teachers Retained / Total Teachers * 100',
        'Days Attended / Total School Days * 100',
        'Programs Completed / Programs Offered * 100',
        'Parent Activities / Total School Activities',
        'Staff Development Hours / Total Hours * 100',
        'Classroom Hours Used / Total Hours Available * 100',
        'Technology Integrated Classrooms / Total Classrooms * 100',
        'Sum of Response Times / Total Requests',
        'Library Materials Checked Out / Total Materials * 100',
        'Students Participating / Total Students * 100'
    ],
    'UoM': ['%', '%', 'Score', '%', 'Level',
            '%', '%', '%', 'Index', '%',
            '%', '%', 'Hours', '%', '%'
    ],
    'Scope': ['School-wide'] * 15,
    'Polarity': ['Positive'] * 15,
    'Type': ['Outcome', 'Outcome', 'Outcome', 'Efficiency', 'Outcome',
             'Outcome', 'Outcome', 'Outcome', 'Outcome', 'Outcome',
             'Efficiency', 'Outcome', 'Efficiency', 'Outcome', 'Outcome'
    ],
    'Frequency': ['Annual'] * 15
}

# Create the KPI DataFrame
kpi_df = pd.DataFrame(kpi_data)

# Display the head of the DataFrame
print(kpi_df.head(15))
# Out:
#                                  Objectives  \
# 0               Improve graduation outcomes
# 1        Increase post-secondary transition
# 2               Enhance student achievement
# 3                Optimize budget allocation
# 4                Boost community engagement
# 5                Maintain teacher retention
# 6                 Ensure student attendance
# 7                   Achieve program success
# 8               Foster parental involvement
# 9                 Support staff development
# 10           Maximize classroom utilization
# 11         Integrate technology in learning
# 12         Streamline maintenance processes
# 13          Increase library resource usage
# 14  Encourage extracurricular participation
#
#                                 What to Measure? KPI #  Link  \
# 0                                Graduation rate   1.1     1
# 1    Enrollment rate in post-secondary education   1.2     2
# 2                 Student test scores and grades   1.3     3
# ...

# %%
import pandas as pd
import numpy as np

# Define the strategic KPIs
strategic_kpis = {
    'Graduation Rate': np.random.uniform(80, 100, 5),
    'Post-Secondary Enrollment Rate': np.random.uniform(60, 90, 5),
    'Student Achievement': np.random.uniform(70, 95, 5),
    'Budget Utilization': np.random.uniform(75, 100, 5),
    'Community Engagement': np.random.randint(5, 20, 5)
}

# Create a DataFrame for strategic KPIs
strategic_df = pd.DataFrame(strategic_kpis)
print(strategic_df)
# Out:
#    Graduation Rate  Post-Secondary Enrollment Rate  Student Achievement  \
# 0        81.972034                       71.718017            73.680737
# 1        91.180504                       62.806108            75.239014
# 2        83.851982                       64.925688            78.464607
# 3        89.965392                       62.552740            85.336472
# 4        80.166758                       71.149825            73.814532
#
#    Budget Utilization  Community Engagement
# 0           81.116429                    13
# 1           80.044534                    18
# 2           84.813462                    12
# 3           79.906574                     7
# 4           95.121633                    11
